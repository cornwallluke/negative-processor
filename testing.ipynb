# %%
import rawpy
import numpy as np
from matplotlib.pyplot import imshow
import matplotlib as mpl
# %matplotlib inline
mpl.rcParams["figure.figsize"] = 50, 50

# %%
raw = rawpy.imread("./neg.NEF")
rgbi = raw.postprocess()
rgb = np.ones(rgb.shape,dtype = np.uint8)*255-rgbi
imshow(rgb)

# %%
# raw.raw_image_visible.copy()
# raw.rgb_xyz_matrix
# raw.rgb_xyz_matrix
raw.raw_image_visible
raw.raw_colors_visible
ohs = np.concatenate((np.zeros((*raw.raw_image_visible.shape, 3)), raw.raw_image_visible.reshape(*raw.raw_image_visible.shape, 1)), axis=2)
ohs.shape
# Out:
# (4012, 6034, 4)

# %%
imshow(rgb[570:800, 2000:2200,:])
awb = rgb[570:800, 2000:2200,:].mean((0,1))

# %%
wbd = (rgb-awb).astype(np.uint8)
imshow(wbd)

# %%
imshow(wbd*2)
